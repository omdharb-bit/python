# %%
# for loop

for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# for i in range(1,10,1):
for i in range(1,10,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(10,1,-3):     #middle value means skiping that no.
  print(i)
# Out:
# 10
# 7
# 4
