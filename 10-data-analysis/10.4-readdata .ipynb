# %% [markdown]
# ### Reading Data From Different Sources

# %%
import pandas as pd
from io import StringIO
Data = '{"employee_name": "James", "email": "james@gmail.com", "job_profile": [{"title1":"Team Lead", "title2":"Sr. Developer"}]}'
df=pd.read_json(StringIO(Data))

import requests

url = "https://en.wikipedia.org/wiki/Mobile_country_code"

headers = {"User-Agent": "Mozilla/5.0"}

response = requests.get(url, headers=headers)

df_list = pd.read_html(response.text)

df = df_list[0]  # first table
print(df.head())
# Out:
#    MCC  MNC Brand      Operator       Status Bands (MHz)  \
# 0    1    1  TEST  Test network  Operational         any
# 1    1    1  TEST  Test network  Operational         any
# 2  999   99   NaN  Internal use  Operational         any
# 3  999  999   NaN  Internal use  Operational         any
#
#                               References and notes
# 0                                              NaN
# 1                                              NaN
# 2  Internal use in private networks, no roaming[6]
# 3  Internal use in private networks, no roaming[6]
# C:\Users\omdha\AppData\Local\Temp\ipykernel_5032\3293054692.py:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_list = pd.read_html(response.text)

# %%
df
# Out:
#    MCC  MNC Brand      Operator       Status Bands (MHz)  \
# 0    1    1  TEST  Test network  Operational         any
# 1    1    1  TEST  Test network  Operational         any
# 2  999   99   NaN  Internal use  Operational         any
# 3  999  999   NaN  Internal use  Operational         any
#
#                               References and notes
# 0                                              NaN
# 1                                              NaN
# 2  Internal use in private networks, no roaming[6]
# 3  Internal use in private networks, no roaming[6]

# %%
df.to_json()
# Out:
# '{"MCC":{"0":1,"1":1,"2":999,"3":999},"MNC":{"0":1,"1":1,"2":99,"3":999},"Brand":{"0":"TEST","1":"TEST","2":null,"3":null},"Operator":{"0":"Test network","1":"Test network","2":"Internal use","3":"Internal use"},"Status":{"0":"Operational","1":"Operational","2":"Operational","3":"Operational"},"Bands (MHz)":{"0":"any","1":"any","2":"any","3":"any"},"References and notes":{"0":null,"1":null,"2":"Internal use in private networks, no roaming[6]","3":"Internal use in private networks, no roaming[6]"}}'

# %%
df.to_json(orient='index')
# Out:
# '{"0":{"MCC":1,"MNC":1,"Brand":"TEST","Operator":"Test network","Status":"Operational","Bands (MHz)":"any","References and notes":null},"1":{"MCC":1,"MNC":1,"Brand":"TEST","Operator":"Test network","Status":"Operational","Bands (MHz)":"any","References and notes":null},"2":{"MCC":999,"MNC":99,"Brand":null,"Operator":"Internal use","Status":"Operational","Bands (MHz)":"any","References and notes":"Internal use in private networks, no roaming[6]"},"3":{"MCC":999,"MNC":999,"Brand":null,"Operator":"Internal use","Status":"Operational","Bands (MHz)":"any","References and notes":"Internal use in private networks, no roaming[6]"}}'

# %%
df.to_json(orient='records')
# Out:
# '[{"MCC":1,"MNC":1,"Brand":"TEST","Operator":"Test network","Status":"Operational","Bands (MHz)":"any","References and notes":null},{"MCC":1,"MNC":1,"Brand":"TEST","Operator":"Test network","Status":"Operational","Bands (MHz)":"any","References and notes":null},{"MCC":999,"MNC":99,"Brand":null,"Operator":"Internal use","Status":"Operational","Bands (MHz)":"any","References and notes":"Internal use in private networks, no roaming[6]"},{"MCC":999,"MNC":999,"Brand":null,"Operator":"Internal use","Status":"Operational","Bands (MHz)":"any","References and notes":"Internal use in private networks, no roaming[6]"}]'

# %%
df = pd.read_csv('wine.data')

# %%
df.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %%
df.to_csv("wine.csv")

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\omdha\anaconda3\lib\site-packages (5.3.0)

# %%
# !pip install html5lib
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: html5lib in c:\users\omdha\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\omdha\anaconda3\lib\site-packages (from html5lib) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\omdha\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\omdha\anaconda3\lib\site-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\omdha\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\omdha\anaconda3\lib\site-packages (from beautifulsoup4) (4.15.0)

# %%
url="https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/"

df=pd.read_html(url)

# %%
df[0]
# Out:
#                                             Bank Name                City  \
# 0                   Metropolitan Capital Bank & Trust             Chicago
# 1                        The Santa Anna National Bank          Santa Anna
# 2                                Pulaski Savings Bank             Chicago
# 3                  The First National Bank of Lindsay             Lindsay
# 4               Republic First Bank dba Republic Bank        Philadelphia
# 5                                       Citizens Bank            Sac City
# 6                            Heartland Tri-State Bank             Elkhart
# 7                                 First Republic Bank       San Francisco
# 8                                      Signature Bank            New York
# 9                                 Silicon Valley Bank         Santa Clara
# 10                                  Almena State Bank              Almena
# 11                         First City Bank of Florida   Fort Walton Beach
# 12                               The First State Bank       Barboursville
# 13                                 Ericson State Bank             Ericson
# 14                   City National Bank of New Jersey              Newark
# 15                                      Resolute Bank              Maumee
# 16                              Louisa Community Bank              Louisa
# 17                               The Enloe State Bank              Cooper
# 18                Washington Federal Bank for Savings             Chicago
# 19    The Farmers and Merchants State Bank of Argonia             Argonia
# 20                                Fayette County Bank          Saint Elmo
# 21  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 22                                     First NBC Bank         New Orleans
# 23                                      Proficio Bank  Cottonwood Heights
# 24                      Seaway Bank and Trust Company             Chicago
#
#             State   Cert                Acquiring Institution  \
# 0        Illinois  57488              First Independence Bank
# 1           Texas   5520            Coleman County State Bank
# 2        Illinois  28611                      Millennium Bank
# 3        Oklahoma   4134               First Bank & Trust Co.
# 4    Pennsylvania  27332    Fulton Bank, National Association
# 5            Iowa   8758            Iowa Trust & Savings Bank
# 6          Kansas  25851               Dream First Bank, N.A.
# 7      California  59017            JPMorgan Chase Bank, N.A.
# 8        New York  57053                  Flagstar Bank, N.A.
# 9      California  24735  First–Citizens Bank & Trust Company
# 10         Kansas  15426                          Equity Bank
# 11        Florida  16748            United Fidelity Bank, fsb
# 12  West Virginia  14361                       MVB Bank, Inc.
# 13       Nebraska  18265           Farmers and Merchants Bank
# 14     New Jersey  21111                      Industrial Bank
# 15           Ohio  58317                   Buckeye State Bank
# 16       Kentucky  58112    Kentucky Farmers Bank Corporation
# 17          Texas  10716                   Legend Bank, N. A.
# 18       Illinois  30570                   Royal Savings Bank
# 19         Kansas  17719                          Conway Bank
# 20       Illinois   1802            United Fidelity Bank, fsb
# 21      Wisconsin  30003  First-Citizens Bank & Trust Company
# 22      Louisiana  58302                         Whitney Bank
# 23           Utah  35495                    Cache Valley Bank
# 24       Illinois  19328                  State Bank of Texas
#
#          Closing Date  Fund  Sort ascending
# 0    January 30, 2026                 10550
# 1       June 27, 2025                 10549
# 2    January 17, 2025                 10548
# 3    October 18, 2024                 10547
# 4      April 26, 2024                 10546
# 5    November 3, 2023                 10545
# 6       July 28, 2023                 10544
# 7         May 1, 2023                 10543
# 8      March 12, 2023                 10540
# 9      March 10, 2023                 10539
# 10   October 23, 2020                 10538
# 11   October 16, 2020                 10537
# 12      April 3, 2020                 10536
# 13  February 14, 2020                 10535
# 14   November 1, 2019                 10534
# 15   October 25, 2019                 10533
# 16   October 25, 2019                 10532
# 17       May 31, 2019                 10531
# 18  December 15, 2017                 10530
# 19   October 13, 2017                 10529
# 20       May 26, 2017                 10528
# 21        May 5, 2017                 10527
# 22     April 28, 2017                 10526
# 23      March 3, 2017                 10525
# 24   January 27, 2017                 10524

# %%
url = "https://en.wikipedia.org/wiki/Mobile_country_code"

pd.read_html(response.text,match="Country",header=0)[0]
# Out:
# C:\Users\omdha\AppData\Local\Temp\ipykernel_5032\1211146801.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_html(response.text,match="Country",header=0)[0]
#      Mobile country code                                    Country ISO 3166  \
# 0                    289                                 A Abkhazia    GE-AB
# 1                    412                                Afghanistan       AF
# 2                    276                                    Albania       AL
# 3                    603                                    Algeria       DZ
# 4                    544  American Samoa (United States of America)       AS
# ..                   ...                                        ...      ...
# 247                  452                                    Vietnam       VN
# 248                  543                        W Wallis and Futuna       WF
# 249                  421                                    Y Yemen       YE
# 250                  645                                   Z Zambia       ZM
# 251                  648                                   Zimbabwe       ZW
#
#                                   Mobile network codes National MNC authority  \
# 0             List of mobile network codes in Abkhazia                    NaN
# 1          List of mobile network codes in Afghanistan                    NaN
# 2              List of mobile network codes in Albania                    NaN
# 3              List of mobile network codes in Algeria                    NaN
# 4       List of mobile network codes in American Samoa                    NaN
# ..                                                 ...                    ...
# 247        List of mobile network codes in the Vietnam                    NaN
# 248  List of mobile network codes in Wallis and Futuna                    NaN
# 249          List of mobile network codes in the Yemen                    NaN
# 250             List of mobile network codes in Zambia                    NaN
# 251           List of mobile network codes in Zimbabwe                    NaN
#
#                       Remarks
# 0    MCC is not listed by ITU
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 247                       NaN
# 248                       NaN
# 249                       NaN
# 250                       NaN
# 251                       NaN
#
# [252 rows x 6 columns]

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\omdha\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\omdha\anaconda3\lib\site-packages (from openpyxl) (2.0.0)

# %%
df_excel=pd.read_excel('Book1.xlsx')

# %%
df_excel.to_pickle('df_excel')

# %%
pd.read_pickle('df_excel')
# Out:
#     Name  Age
# 0     OM   19
# 1  Dhruv   18
# 2    Ram   20
